# %% [markdown]
# Cargando Librerias

# %%
import numpy
import pandas as pd 
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# Gráficas no dirigidas

# %%
G = nx.Graph()
G.add_nodes_from([2,'x','y',9])
G.add_edges_from([(2,'x'),('x','y'),('y',9)])
nx.draw(G)
plt.show()

# %% [markdown]
# Número de vértices y aristas de una gráfica

# %%
G.order()
G.size()   
print(G.order())
print(G.size())
# Out:
# 4
# 3

# %% [markdown]
# Vista de nodos

# %%
G.nodes()
# Out:
# NodeView((2, 'x', 'y', 9))

# %% [markdown]
# Vista de aristas

# %%
G.edges()
# Out:
# EdgeView([(2, 'x'), ('x', 'y'), ('y', 9)])

# %% [markdown]
# Longitud de la gráfica

# %%
print(len(G))
# Out:
# 4

# %% [markdown]
# Modificaciones a la gráfica

# %%
G.add_node(12)				#agrega un nodo
nx.draw(G)
plt.show()	
G.add_edge(23,45)			#agrega aristas, incluso si no tiene nodos
nx.draw(G)
plt.show()	
G.remove_node(9)				#elimina nodos
nx.draw(G)
plt.show()	
G.remove_edges_from( [(2,'x'),(23,45)] ) 
nx.draw(G)
plt.show()
